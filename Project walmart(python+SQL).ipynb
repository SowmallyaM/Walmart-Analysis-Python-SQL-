# %%
# !pip install kaggle
# Out:
# ...
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/181.2 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/181.2 kB 435.7 kB/s eta 0:00:01
#    ----------------- --------------------- 81.9/181.2 kB 651.6 kB/s eta 0:00:01
#    ------------------------- ------------ 122.9/181.2 kB 901.1 kB/s eta 0:00:01
#    ------------------------------------ - 174.1/181.2 kB 803.1 kB/s eta 0:00:01
#    -------------------------------------- 181.2/181.2 kB 727.7 kB/s eta 0:00:00
# ...

# %%
#download dataset using kaggle api
import kaggle
# !kaggle datasets download najir0123/walmart-10k-sales-datasets -f Walmart.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/najir0123/walmart-10k-sales-datasets
# License(s): MIT
# Walmart.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
#importing liberies
import pandas as pd
df=pd.read_csv('Walmart.csv')

# %%
df
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %% [markdown]
# # **DATA CLEANING**

# %%
#changing the columns name
df.columns=df.columns.str.lower()
df
# Out:
#        invoice_id   branch         city                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
#all duplicates and null
df.duplicated().sum()
# Out:
# 51

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
#cheak null 
df.isnull().sum()
# Out:
# invoice_id         0
# branch             0
# city               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
#droping null values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# invoice_id        0
# branch            0
# city              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
df['unit_price']=df['unit_price'].str.replace('$','').astype(float)
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df['total_price']=df['unit_price'] * df['quantity']

# %%
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin  \
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48
#
#    total_price
# 0       522.83
# 1        76.40
# 2       324.31
# 3       465.76
# 4       604.17

# %% [markdown]
# ### **Conentiong to mysql**

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/45.0 kB 262.6 kB/s eta 0:00:01
#    ------------------------------------ --- 41.0/45.0 kB 330.3 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 222.6 kB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine

# %%
host= 'localhost'
port= 3306
user= 'root'
password= 'Openmysql12'
mysql_db = 'walmart_db'

# %%
engine=create_engine('mysql+pymysql://root:Openmysql12@localhost/walmart_db')
try:
    engine
    print('conection sucessful')
except:
    print('not conected')
# Out:
# conection sucessful

# %%
table_name = 'walmart'

df.to_sql(
    name=table_name,
    con=engine,
    if_exists='append',     # or 'append' / 'fail'
    index=False              # don’t write DataFrame index as a column
)
# Out:
# 9969
